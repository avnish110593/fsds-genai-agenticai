# %% [markdown]
# # python

# %%
5
# Out:
# 5

# %%
3
# Out:
# 3

# %%
a = 5
a
# Out:
# 5

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # work with number

# %%
5
# Out:
# 5

# %%
3
# Out:
# 3

# %%
3 + 5
# Out:
# 8

# %%
10 - 5
# Out:
# 5

# %%
10 + 5
# Out:
# 15

# %%
10 / 5 #float division
# Out:
# 2.0

# %%
10 // 5
# Out:
# 2

# %%
10 * 5
# Out:
# 50

# %%
_
# Out:
# 50

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
10 % 5 #modulus
# Out:
# 0

# %%
3 * 2
# Out:
# 6

# %%
_ + 3
# Out:
# 9

# %%
_ + 3
# Out:
# 12

# %%
_ - 2
# Out:
# 10

# %%
10*3-2+1
# Out:
# 29

# %%
10*3-(2+1)
# Out:
# 27

# %%
5 + 1
# Out:
# 6

# %%
2 + 3
10 - 3
10 * 3
10 / 3
# Out:
# 3.3333333333333335

# %%
print(2+3)
print(10-3)
print(10*3)
print(10/3)
# Out:
# 5
# 7
# 30
# 3.3333333333333335

# %%
#4th -- work with text

# %%
apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 apple
#
# NameError: name 'apple' is not defined

# %%
'apple'
# Out:
# 'apple'

# %%
"apple'
# Out:
#   Cell In[23], line 1
#     "apple'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"apple"
# Out:
# 'apple'

# %%
''' apple '''
# Out:
# ' apple '

# %%
'apple 
fruit 
is 
good for health'
# Out:
#   Cell In[26], line 1
#     'apple
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"apple 
fruit 
is 
good for health"
# Out:
#   Cell In[27], line 1
#     "apple
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''apple 
fruit 
is 
good for health'''
# Out:
# 'apple \nfruit \nis \ngood for health'

# %%
v = 5
v
# Out:
# 5

# %%
id(v)
# Out:
# 140726172165160

# %%
var = 10
var
# Out:
# 10

# %%
var
# Out:
# 10

# %%
nit = 25
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 nit = 25
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit = 25
nit
# Out:
# 25

# %%
1nit = 30
1nit
# Out:
#   Cell In[35], line 1
#     1nit = 30
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 30
nit1
# Out:
# 30

# %%
23a = 56
# Out:
#   Cell In[37], line 1
#     23a = 56
#      ^
# SyntaxError: invalid decimal literal

# %%
var@ = 67
var@
# Out:
#   Cell In[38], line 1
#     var@ = 67
#          ^
# SyntaxError: invalid syntax

# %%
var_ = 6
var_
# Out:
# 6

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import = 45
import
# Out:
#   Cell In[41], line 1
#     import = 45
#            ^
# SyntaxError: invalid syntax

# %% [raw]
# for = 3
# for

# %%
For = 3
For
# Out:
# 3

# %% [raw]
# 1- case sensitive
# 2- doesnot start with digit but end with digit
# 3- keyword not define as variable
# 4- special character are not allowed
#
# variable is python we are completed

# %% [markdown]
# # 5th

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
i = 5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
5 = i
# Out:
#   Cell In[5], line 1
#     5 = i
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
f = 110.34 
f
# Out:
# 110.34

# %%
type(f)
# Out:
# float

# %%
2e0
# Out:
# 2.0

# %%
2e1
# Out:
# 20.0

# %%
-3e2
# Out:
# -300.0

# %%
4E3
# Out:
# 4000.0

# %%
2.4e2
# Out:
# 240.0

# %%
True
# Out:
# True

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
None

# %%
True + False
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
t = True
f = False

# %%
print(t + f)
print(t - f)
print(t * f)
print(f / t)
# Out:
# 1
# 1
# 0
# 0.0

# %%
f // t
# Out:
# 0

# %%
t
# Out:
# True

# %%
type(t)
# Out:
# bool

# %%
type(f)
# Out:
# bool

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c = 10 + 20j
d = 20 + 30j

# %%
print(c + d)
# Out:
# (30+50j)

# %%
# int, float , complex, bool

# %%
a = '5.5'
type(a)
# Out:
# str

# %% [markdown]
# #6th -- string

# %%
s = welcome
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s = welcome
#       2 s
#
# NameError: name 'welcome' is not defined

# %%
True
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
s = 'welcome'

# %%
s
# Out:
# 'welcome'

# %%
id(s)
# Out:
# 2988062376848

# %%
s
# Out:
# 'welcome'

# %%
len(s)
# Out:
# 7

# %%
s = 'welcome'
s
# Out:
# 'welcome'

# %%
s1 = "welcome to nit"
s1
# Out:
# 'welcome to nit'

# %%
s2 = ''' welcome 
            to
               nit technology'''
s2
# Out:
# ' welcome \n            to\n               nit technology'

# %%
s
# Out:
# 'welcome'

# %%
s4 = 'welcome'
s4
# Out:
# 'welcome'

# %%
print(s)
print(s4)
# Out:
# welcome
# welcome

# %%
print(id(s))
print(id(s4))
# Out:
# 2988062376848
# 2988062376848

# %%
s
# Out:
# 'welcome'

# %%
s[0] #forward index
# Out:
# 'w'

# %%
s
# Out:
# 'welcome'

# %%
s[6]
# Out:
# 'e'

# %%
s[4]
# Out:
# 'o'

# %%
len(s)
# Out:
# 7

# %%
s
# Out:
# 'welcome'

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[-1]
# Out:
# 'e'

# %%
s[-3]
# Out:
# 'o'

# %%
s
# Out:
# 'welcome'

# %%
s[-5]
# Out:
# 'l'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[:]
# Out:
# 'welcome'

# %%
s
# Out:
# 'welcome'

# %%
s[1:6] #forward slicing
# Out:
# 'elcom'

# %%
s
# Out:
# 'welcome'

# %%
s[2:]
# Out:
# 'lcome'

# %%
s
# Out:
# 'welcome'

# %%
s[:7]
# Out:
# 'welcome'

# %%
s[:5]
# Out:
# 'welco'

# %%
s
# Out:
# 'welcome'

# %%
s[:10000]
# Out:
# 'welcome'

# %%
s[1000 : ]
# Out:
# ''

# %%
s [ : 10000]
# Out:
# 'welcome'

# %%
s
# Out:
# 'welcome'

# %%
s[-1:]
# Out:
# 'e'

# %%
s
# Out:
# 'welcome'

# %%
s[-6:]
# Out:
# 'elcome'

# %%
s
# Out:
# 'welcome'

# %%
s[-7:-4] # backward slicing
# Out:
# 'wel'
